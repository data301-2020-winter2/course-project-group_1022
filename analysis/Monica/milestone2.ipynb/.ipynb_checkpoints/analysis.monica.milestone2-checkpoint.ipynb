# %%
from Scripts import project_functions
wd = project_functions.load_and_process('2009_2020_annual_surgical_wait_times.csv')
wd
# Out:
#           year                     h_a                         hosp  \
# 0      2009/10  All Health Authorities               All Facilities
# 1      2009/10  All Health Authorities               All Facilities
# 2      2009/10  All Health Authorities               All Facilities
# 3      2009/10  All Health Authorities               All Facilities
# 4      2009/10  All Health Authorities               All Facilities
# ...        ...                     ...                          ...
# 37657  2019/20        Vancouver Island  West Coast General Hospital
# 37659  2019/20        Vancouver Island  West Coast General Hospital
# 37661  2019/20        Vancouver Island  West Coast General Hospital
# 37662  2019/20        Vancouver Island  West Coast General Hospital
# 37664  2019/20        Vancouver Island  West Coast General Hospital
#
#                          prcd  waiting    comp  wait_med  wait_90  \
# 0              Abdominoplasty       52     100       9.1     42.6
# ...

# %%
wd.

# %%
#This is my initial EDA
#These are the steps to bring the file into pandas, 
#rename the columns so they are less clunky and 
#removed all the nan values.
#This would be what we can use for Step 3 of Task 3
#Feel free to adjust the  names I chose
#I don't think we need to drop any columns. The only columns to add would be if we want wait times in days (right now they are in weeks) or if we want to multiply the # waiting by the wait_med. 
import pandas as pd
import numpy as np
wd =  (
        pd.read_csv('2009_2020_annual_surgical_wait_times.csv')
        .rename(columns={'FISCAL_YEAR':'year', 'HEALTH_AUTHORITY': 'h_a', 'HOSPITAL_NAME':'hosp', 'PROCEDURE_GROUP': 'prcd', 'WAITING':'waiting', 'COMPLETED': 'comp', 'COMPLETED_50TH_PERCENTILE': 'wait_med', 'COMPLETED_90TH_PERCENTILE':'wait_90'})
        .dropna()
)
wd.head()
# Out:
#       year                     h_a            hosp                    prcd  \
# 0  2009/10  All Health Authorities  All Facilities          Abdominoplasty
# 1  2009/10  All Health Authorities  All Facilities    All Other Procedures
# 2  2009/10  All Health Authorities  All Facilities          All Procedures
# 3  2009/10  All Health Authorities  All Facilities  Aortic Aneurysm Repair
# 4  2009/10  All Health Authorities  All Facilities            Appendectomy
#
#   waiting     comp  wait_med  wait_90
# 0      52      100       9.1     42.6
# 1   1,347    6,287       4.0     17.1
# 2  72,056  219,284       5.3     24.3
# 3      96      365       3.7     13.5
# 4      19       88       3.7      9.1

# %%
#These are the steps to convert waiting and comp columns from str to int 
#I had to get rid of the commas 
#I changed the <5 people waiting or <5 procedures done arbitrarily over to the value 3 (half way between 1 and 5)
#We just need to make this intoa function and do step3 of task 2...which I think will be easy enough
wd['waiting'] = (
                  wd['waiting'].str.replace(',','')
                                .str.replace('<5','3')
)

wd['comp'] = (
               wd['comp'].str.replace(',','')
                          .str.replace('<5','3')
)

wd['waiting'] = pd.to_numeric(wd['waiting'])
wd['comp'] = pd.to_numeric(wd['comp'])
wd.head()
# Out:
#       year                     h_a            hosp                    prcd  \
# 0  2009/10  All Health Authorities  All Facilities          Abdominoplasty
# 1  2009/10  All Health Authorities  All Facilities    All Other Procedures
# 2  2009/10  All Health Authorities  All Facilities          All Procedures
# 3  2009/10  All Health Authorities  All Facilities  Aortic Aneurysm Repair
# 4  2009/10  All Health Authorities  All Facilities            Appendectomy
#
#    waiting    comp  wait_med  wait_90
# 0       52     100       9.1     42.6
# 1     1347    6287       4.0     17.1
# 2    72056  219284       5.3     24.3
# 3       96     365       3.7     13.5
# 4       19      88       3.7      9.1

# %%
#To demonstrate that the waiting and comp values are now numeric
wd.describe()
# Out:
#             waiting           comp      wait_med       wait_90
# count  30266.000000   30266.000000  30266.000000  30266.000000
# mean     174.441816     506.071004      7.421086     22.002425
# std     1779.251684    5107.433067      7.163949     17.150503
# min        0.000000       5.000000      0.000000      0.000000
# 25%        3.000000      17.000000      3.100000     10.300000
# 50%       13.000000      52.000000      5.300000     18.000000
# 75%       54.000000     171.000000      9.000000     29.500000
# max    93941.000000  248901.000000    142.600000    256.100000

# %%
#Here are a couple of other commands that I thought would be nice to chain and make into a function 
#Looking at only specific procedures over the years....Knees, Other Ortho, Prostate, Uterine, etc
wd_all_knee= wd[(wd['h_a'] == 'All Health Authorities') & (wd['prcd']  == 'Knee Replacement')]
wd_all_knee
# Out:
#           year                     h_a            hosp              prcd  \
# 43     2009/10  All Health Authorities  All Facilities  Knee Replacement
# 3397   2010/11  All Health Authorities  All Facilities  Knee Replacement
# 6833   2011/12  All Health Authorities  All Facilities  Knee Replacement
# 10303  2012/13  All Health Authorities  All Facilities  Knee Replacement
# 13768  2013/14  All Health Authorities  All Facilities  Knee Replacement
# 17216  2014/15  All Health Authorities  All Facilities  Knee Replacement
# 20627  2015/16  All Health Authorities  All Facilities  Knee Replacement
# 24033  2016/17  All Health Authorities  All Facilities  Knee Replacement
# 27471  2017/18  All Health Authorities  All Facilities  Knee Replacement
# 30920  2018/19  All Health Authorities  All Facilities  Knee Replacement
# 34315  2019/20  All Health Authorities  All Facilities  Knee Replacement
#
#        waiting   comp  wait_med  wait_90
# 43        3354   6466      12.0     35.7
# ...

# %%
wd_all_ortho= wd[(wd['h_a'] == 'All Health Authorities') & (wd['prcd']  == 'Other Orthopaedic Surgery')]
wd_all_ortho
# Out:
#           year                     h_a            hosp  \
# 60     2009/10  All Health Authorities  All Facilities
# 3414   2010/11  All Health Authorities  All Facilities
# 6850   2011/12  All Health Authorities  All Facilities
# 10320  2012/13  All Health Authorities  All Facilities
# 13785  2013/14  All Health Authorities  All Facilities
# 17233  2014/15  All Health Authorities  All Facilities
# 20644  2015/16  All Health Authorities  All Facilities
# 24050  2016/17  All Health Authorities  All Facilities
# 27488  2017/18  All Health Authorities  All Facilities
# 30937  2018/19  All Health Authorities  All Facilities
# 34332  2019/20  All Health Authorities  All Facilities
#
#                             prcd  waiting  comp  wait_med  wait_90
# 60     Other Orthopaedic Surgery     2568  6422       5.6     28.9
# 3414   Other Orthopaedic Surgery     2656  6424       6.1     31.4
# 6850   Other Orthopaedic Surgery     2845  6879       6.0     29.6
# ...

# %%
wd_all_prostate= wd[(wd['h_a'] == 'All Health Authorities') & (wd['prcd']  == 'Prostate Surgery')]
wd_all_prostate
# Out:
#           year                     h_a            hosp              prcd  \
# 63     2009/10  All Health Authorities  All Facilities  Prostate Surgery
# 3417   2010/11  All Health Authorities  All Facilities  Prostate Surgery
# 6853   2011/12  All Health Authorities  All Facilities  Prostate Surgery
# 10323  2012/13  All Health Authorities  All Facilities  Prostate Surgery
# 13788  2013/14  All Health Authorities  All Facilities  Prostate Surgery
# 17236  2014/15  All Health Authorities  All Facilities  Prostate Surgery
# 20647  2015/16  All Health Authorities  All Facilities  Prostate Surgery
# 24053  2016/17  All Health Authorities  All Facilities  Prostate Surgery
# 27491  2017/18  All Health Authorities  All Facilities  Prostate Surgery
# 30940  2018/19  All Health Authorities  All Facilities  Prostate Surgery
# 34335  2019/20  All Health Authorities  All Facilities  Prostate Surgery
#
#        waiting  comp  wait_med  wait_90
# 63        1330  5113       4.9     19.6
# ...

# %%
wd_all_uterine= wd[(wd['h_a'] == 'All Health Authorities') & (wd['prcd']  == 'Uterine Surgery')]
wd_all_uterine
# Out:
#           year                     h_a            hosp             prcd  \
# 79     2009/10  All Health Authorities  All Facilities  Uterine Surgery
# 3433   2010/11  All Health Authorities  All Facilities  Uterine Surgery
# 6869   2011/12  All Health Authorities  All Facilities  Uterine Surgery
# 10339  2012/13  All Health Authorities  All Facilities  Uterine Surgery
# 13804  2013/14  All Health Authorities  All Facilities  Uterine Surgery
# 17252  2014/15  All Health Authorities  All Facilities  Uterine Surgery
# 20663  2015/16  All Health Authorities  All Facilities  Uterine Surgery
# 24069  2016/17  All Health Authorities  All Facilities  Uterine Surgery
# 27507  2017/18  All Health Authorities  All Facilities  Uterine Surgery
# 30956  2018/19  All Health Authorities  All Facilities  Uterine Surgery
# 34351  2019/20  All Health Authorities  All Facilities  Uterine Surgery
#
#        waiting   comp  wait_med  wait_90
# 79        2773  11980       5.0     17.7
# ...

# %%
#Here would be how to look at a specific hospital for each procedure type by individual year
wd_kgh_19_20 = wd[(wd['hosp'] == 'Kelowna General Hospital') & (wd['year'] == '2019/20')]
wd_kgh_19_20
# Out:
#           year       h_a                      hosp  \
# 35360  2019/20  Interior  Kelowna General Hospital
# 35361  2019/20  Interior  Kelowna General Hospital
# 35362  2019/20  Interior  Kelowna General Hospital
# 35363  2019/20  Interior  Kelowna General Hospital
# 35364  2019/20  Interior  Kelowna General Hospital
# ...        ...       ...                       ...
# 35437  2019/20  Interior  Kelowna General Hospital
# 35438  2019/20  Interior  Kelowna General Hospital
# 35439  2019/20  Interior  Kelowna General Hospital
# 35440  2019/20  Interior  Kelowna General Hospital
# 35441  2019/20  Interior  Kelowna General Hospital
#
#                                       prcd  waiting   comp  wait_med  wait_90
# 35360                       Abdominoplasty       27     21      33.4     53.9
# 35361                 All Other Procedures      110    367       4.6     27.3
# 35362                       All Procedures     4239  12212       8.0     35.1
# ...

# %%
wd_kgh_09_10 = wd[(wd['hosp'] == 'Kelowna General Hospital') & (wd['year'] == '2009/10')]
wd_kgh_09_10
# Out:
#          year       h_a                      hosp  \
# 1088  2009/10  Interior  Kelowna General Hospital
# 1089  2009/10  Interior  Kelowna General Hospital
# 1090  2009/10  Interior  Kelowna General Hospital
# 1093  2009/10  Interior  Kelowna General Hospital
# 1094  2009/10  Interior  Kelowna General Hospital
# ...       ...       ...                       ...
# 1165  2009/10  Interior  Kelowna General Hospital
# 1166  2009/10  Interior  Kelowna General Hospital
# 1167  2009/10  Interior  Kelowna General Hospital
# 1168  2009/10  Interior  Kelowna General Hospital
# 1169  2009/10  Interior  Kelowna General Hospital
#
#                                      prcd  waiting   comp  wait_med  wait_90
# 1088                 All Other Procedures       61    290       4.0     11.7
# 1089                       All Procedures     4053  10397       6.0     26.3
# 1090               Aortic Aneurysm Repair        3     42       2.9     12.7
# ...

# %%
#This looks at total procedures at a specific hospital over the years
wd_kgh_all = wd[(wd['prcd'] == 'All Procedures') & (wd['hosp'] == 'Kelowna General Hospital')]
wd_kgh_all
# Out:
#           year       h_a                      hosp            prcd  waiting  \
# 1089   2009/10  Interior  Kelowna General Hospital  All Procedures     4053
# 4442   2010/11  Interior  Kelowna General Hospital  All Procedures     3650
# 7874   2011/12  Interior  Kelowna General Hospital  All Procedures     3578
# 11357  2012/13  Interior  Kelowna General Hospital  All Procedures     3327
# 14807  2013/14  Interior  Kelowna General Hospital  All Procedures     3611
# 18258  2014/15  Interior  Kelowna General Hospital  All Procedures     3884
# 21676  2015/16  Interior  Kelowna General Hospital  All Procedures     4274
# 25079  2016/17  Interior  Kelowna General Hospital  All Procedures     4295
# 28513  2017/18  Interior  Kelowna General Hospital  All Procedures     4520
# 31959  2018/19  Interior  Kelowna General Hospital  All Procedures     4272
# 35362  2019/20  Interior  Kelowna General Hospital  All Procedures     4239
#
#         comp  wait_med  wait_90
# ...

# %%
wd_vgh_all = wd[(wd['prcd'] == 'All Procedures') & (wd['hosp'] == 'Vancouver General Hospital')]
wd_vgh_all
#hmm this is interesting.  Why is VGH doing less procedures now than they completed in the 2009-2015
# What happened in 2016/2017 that there was a drop?
# Out:
#           year                h_a                        hosp            prcd  \
# 2704   2009/10  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 6133   2010/11  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 9595   2011/12  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 13066  2012/13  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 16504  2013/14  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 19933  2014/15  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 23336  2015/16  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 26749  2016/17  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 30183  2017/18  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 33622  2018/19  Vancouver Coastal  Vancouver General Hospital  All Procedures
# 37021  2019/20  Vancouver Coastal  Vancouver General Hospital  All Procedures
#
# ...

# %%
wd.describe().T
# Out:
#             count        mean          std  min   25%   50%    75%       max
# waiting   30266.0  174.441816  1779.251684  0.0   3.0  13.0   54.0   93941.0
# comp      30266.0  506.071004  5107.433067  5.0  17.0  52.0  171.0  248901.0
# wait_med  30266.0    7.421086     7.163949  0.0   3.1   5.3    9.0     142.6
# wait_90   30266.0   22.002425    17.150503  0.0  10.3  18.0   29.5     256.1

# %%
import pandas_profiling as pdp
wd.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-03-11 22:42:17.642337&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_style("ticks")
sns.despine

plot1 = sns.countplot(data=wd, y = 'h_a')
plot1.set_title('Numbers by Health Authority')
plot1.spines['right'].set_visible(False)
plot1.spines['top'].set_visible(False)
plot1
# Out:
# <AxesSubplot:title={'center':'Completed cases by Health Authority'}, xlabel='Cases completed', ylabel='h_a'>

# %%
plot2 = sns.countplot(data=wd, y = 'year')
plot2.set_title('Data by year')
plot2.spines['right'].set_visible(False)
plot2.spines['top'].set_visible(False)
plot2
# Out:
# <AxesSubplot:title={'center':'Data by year'}, xlabel='count', ylabel='year'>

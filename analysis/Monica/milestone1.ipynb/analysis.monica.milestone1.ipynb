# %%
import pandas as pd
import numpy as np
waitdata_raw = pd.read_csv('2009_2020-annual-surgical_wait_times.csv')
waitdata_raw.head(100)
# Out:
#    FISCAL_YEAR        HEALTH_AUTHORITY  \
# 0      2009/10  All Health Authorities
# 1      2009/10  All Health Authorities
# 2      2009/10  All Health Authorities
# 3      2009/10  All Health Authorities
# 4      2009/10  All Health Authorities
# ..         ...                     ...
# 95     2009/10                  Fraser
# 96     2009/10                  Fraser
# 97     2009/10                  Fraser
# 98     2009/10                  Fraser
# 99     2009/10                  Fraser
#
#                                      HOSPITAL_NAME         PROCEDURE_GROUP  \
# 0                                   All Facilities          Abdominoplasty
# 1                                   All Facilities    All Other Procedures
# 2                                   All Facilities          All Procedures
# 3                                   All Facilities  Aortic Aneurysm Repair
# 4                                   All Facilities            Appendectomy
# ...

# %%
waitdata_raw.head(20)
# Out:
#    FISCAL_YEAR        HEALTH_AUTHORITY   HOSPITAL_NAME  \
# 0      2009/10  All Health Authorities  All Facilities
# 1      2009/10  All Health Authorities  All Facilities
# 2      2009/10  All Health Authorities  All Facilities
# 3      2009/10  All Health Authorities  All Facilities
# 4      2009/10  All Health Authorities  All Facilities
# 5      2009/10  All Health Authorities  All Facilities
# 6      2009/10  All Health Authorities  All Facilities
# 7      2009/10  All Health Authorities  All Facilities
# 8      2009/10  All Health Authorities  All Facilities
# 9      2009/10  All Health Authorities  All Facilities
# 10     2009/10  All Health Authorities  All Facilities
# 11     2009/10  All Health Authorities  All Facilities
# 12     2009/10  All Health Authorities  All Facilities
# 13     2009/10  All Health Authorities  All Facilities
# 14     2009/10  All Health Authorities  All Facilities
# 15     2009/10  All Health Authorities  All Facilities
# ...

# %%
waitdata_raw.shape
# Out:
# (37665, 8)

# %%
waitdata_raw_shape = waitdata_raw.shape
waitdata_raw_shape
# Out:
# (37665, 8)

# %%
wdr = waitdata_raw
wdr.loc[10:20, "WAITING":"COMPLETED"]
# Out:
#    WAITING COMPLETED
# 10     473     1,112
# 11   1,449     1,743
# 12  12,982    47,146
# 13   1,608     5,713
# 14     185       625
# 15      77       662
# 16      85       929
# 17       5        63
# 18     465     1,469
# 19   1,063     5,702
# 20   2,158     5,251

# %%
wdr.loc[1000, "WAITING"]
# Out:
# '10'

# %%
wdr.loc[20000]
# Out:
# FISCAL_YEAR                                     2014/15
# HEALTH_AUTHORITY                      Vancouver Coastal
# HOSPITAL_NAME                Vancouver General Hospital
# PROCEDURE_GROUP                           Thyroidectomy
# WAITING                                              67
# COMPLETED                                           136
# COMPLETED_50TH_PERCENTILE                          14.1
# COMPLETED_90TH_PERCENTILE                          46.1
# Name: 20000, dtype: object

# %%
wdr.loc[10000:10020, ["WAITING"]]
# Out:
#       WAITING
# 10000      52
# 10001      19
# 10002      <5
# 10003       0
# 10004      39
# 10005      12
# 10006      <5
# 10007     175
# 10008      18
# 10009      69
# 10010     176
# 10011      22
# 10012      82
# 10013       8
# 10014       0
# 10015      16
# 10016     112
# 10017      40
# 10018      23
# 10019      71
# 10020      <5

# %%
wdr.iloc[-9:]
# Out:
#       FISCAL_YEAR  HEALTH_AUTHORITY                HOSPITAL_NAME  \
# 37656     2019/20  Vancouver Island  West Coast General Hospital
# 37657     2019/20  Vancouver Island  West Coast General Hospital
# 37658     2019/20  Vancouver Island  West Coast General Hospital
# 37659     2019/20  Vancouver Island  West Coast General Hospital
# 37660     2019/20  Vancouver Island  West Coast General Hospital
# 37661     2019/20  Vancouver Island  West Coast General Hospital
# 37662     2019/20  Vancouver Island  West Coast General Hospital
# 37663     2019/20  Vancouver Island  West Coast General Hospital
# 37664     2019/20  Vancouver Island  West Coast General Hospital
#
#                 PROCEDURE_GROUP WAITING COMPLETED  COMPLETED_50TH_PERCENTILE  \
# 37656          Prostate Surgery      10        58                        6.3
# 37657            Rectal Surgery       5        13                        4.1
# 37658              Skin Surgery      <5        <5                        NaN
# ...

# %%
wdr_sort = wdr.sort_values(by = "FISCAL_YEAR", ascending = False)
wdr_sort.head()
# Out:
#       FISCAL_YEAR  HEALTH_AUTHORITY                HOSPITAL_NAME  \
# 37664     2019/20  Vancouver Island  West Coast General Hospital
# 35411     2019/20          Interior     Kelowna General Hospital
# 35409     2019/20          Interior     Kelowna General Hospital
# 35408     2019/20          Interior     Kelowna General Hospital
# 35407     2019/20          Interior     Kelowna General Hospital
#
#                  PROCEDURE_GROUP WAITING COMPLETED  COMPLETED_50TH_PERCENTILE  \
# 37664      Wound/Laceration Care      <5        11                        2.1
# 35411              Nasal Surgery      92       127                        9.7
# 35409              Mastoidectomy       6         6                        3.1
# 35408                 Mastectomy      25       230                        2.9
# 35407  Male Reproductive Surgery      28        68                        5.1
#
#        COMPLETED_90TH_PERCENTILE
# 37664                        3.3
# 35411                       42.9
# ...

# %%
wdr.describe(include = 'all')
# Out:
#        FISCAL_YEAR HEALTH_AUTHORITY   HOSPITAL_NAME PROCEDURE_GROUP WAITING  \
# count        37665            37665           37665           37665   37665
# unique          11                7              63              85    1525
# top        2011/12           Fraser  All Facilities  All Procedures      <5
# freq          3469             8444            6168             726    9649
# mean           NaN              NaN             NaN             NaN     NaN
# std            NaN              NaN             NaN             NaN     NaN
# min            NaN              NaN             NaN             NaN     NaN
# 25%            NaN              NaN             NaN             NaN     NaN
# 50%            NaN              NaN             NaN             NaN     NaN
# 75%            NaN              NaN             NaN             NaN     NaN
# max            NaN              NaN             NaN             NaN     NaN
#
# ...

# %%
waiting = wdr[['WAITING']]
waiting.mean()
# Out:
# Series([], dtype: float64)

# %%
wdr.mean()
# Out:
# COMPLETED_50TH_PERCENTILE     7.421086
# COMPLETED_90TH_PERCENTILE    22.002425
# dtype: float64

# %%
waitingSum = wdr[['WAITING']].sum()
waitingSum
# Out:
# WAITING    521,34772,05696195304381,8303762304731,44912,9...
# dtype: object

# %%
waiting_column = wdr['WAITING']
waiting_column
# Out:
# 0            52
# 1         1,347
# 2        72,056
# 3            96
# 4            19
#           ...
# 37660        <5
# 37661        10
# 37662        <5
# 37663         0
# 37664        <5
# Name: WAITING, Length: 37665, dtype: object

# %%
waiting_freq = waiting_column.value_counts()
waiting_freq
# Out:
# <5       9649
# 0        6455
# 5        1223
# 6        1022
# 7         821
#          ...
# 832         1
# 738         1
# 733         1
# 1,874       1
# 555         1
# Name: WAITING, Length: 1525, dtype: int64

# %%
wl = waitdata_raw.rename(columns={'FISCAL_YEAR':'year', 'HEALTH_AUTHORITY': 'HA', 'HOSPITAL_NAME':'hosp', 'PROCEDURE_GROUP': 'prcd', 'WAITING':'waiting', 'COMPLETED': 'comp', 'COMPLETED_50TH_PERCENTILE': 'median_wait_w', 'COMPLETED_90TH_PERCENTILE':'wait_90_w'})
wl.head()
# Out:
#       year                      HA            hosp                    prcd  \
# 0  2009/10  All Health Authorities  All Facilities          Abdominoplasty
# 1  2009/10  All Health Authorities  All Facilities    All Other Procedures
# 2  2009/10  All Health Authorities  All Facilities          All Procedures
# 3  2009/10  All Health Authorities  All Facilities  Aortic Aneurysm Repair
# 4  2009/10  All Health Authorities  All Facilities            Appendectomy
#
#   waiting     comp  median_wait_w  wait_90_w
# 0      52      100            9.1       42.6
# 1   1,347    6,287            4.0       17.1
# 2  72,056  219,284            5.3       24.3
# 3      96      365            3.7       13.5
# 4      19       88            3.7        9.1

# %%
comp_day = wl.assign(median_wait_d = wl['median_wait_w']*7)
comp_day.head()
# Out:
#       year                      HA            hosp                    prcd  \
# 0  2009/10  All Health Authorities  All Facilities          Abdominoplasty
# 1  2009/10  All Health Authorities  All Facilities    All Other Procedures
# 2  2009/10  All Health Authorities  All Facilities          All Procedures
# 3  2009/10  All Health Authorities  All Facilities  Aortic Aneurysm Repair
# 4  2009/10  All Health Authorities  All Facilities            Appendectomy
#
#   waiting     comp  median_wait_w  wait_90_w  median_wait_d
# 0      52      100            9.1       42.6           63.7
# 1   1,347    6,287            4.0       17.1           28.0
# 2  72,056  219,284            5.3       24.3           37.1
# 3      96      365            3.7       13.5           25.9
# 4      19       88            3.7        9.1           25.9

# %%
comp_day = comp_day.assign(wait_90th_d = wl['wait_90_w']*7)
comp_day.head()
# Out:
#       year                      HA            hosp                    prcd  \
# 0  2009/10  All Health Authorities  All Facilities          Abdominoplasty
# 1  2009/10  All Health Authorities  All Facilities    All Other Procedures
# 2  2009/10  All Health Authorities  All Facilities          All Procedures
# 3  2009/10  All Health Authorities  All Facilities  Aortic Aneurysm Repair
# 4  2009/10  All Health Authorities  All Facilities            Appendectomy
#
#   waiting     comp  median_wait_w  wait_90_w  median_wait_d  wait_90th_d
# 0      52      100            9.1       42.6           63.7        298.2
# 1   1,347    6,287            4.0       17.1           28.0        119.7
# 2  72,056  219,284            5.3       24.3           37.1        170.1
# 3      96      365            3.7       13.5           25.9         94.5
# 4      19       88            3.7        9.1           25.9         63.7

# %%
wl_19_20 = wl[wl['year'] == '2019/20']
wl_19_20
# Out:
#           year                      HA                         hosp  \
# 34273  2019/20  All Health Authorities               All Facilities
# 34274  2019/20  All Health Authorities               All Facilities
# 34275  2019/20  All Health Authorities               All Facilities
# 34276  2019/20  All Health Authorities               All Facilities
# 34277  2019/20  All Health Authorities               All Facilities
# ...        ...                     ...                          ...
# 37660  2019/20        Vancouver Island  West Coast General Hospital
# 37661  2019/20        Vancouver Island  West Coast General Hospital
# 37662  2019/20        Vancouver Island  West Coast General Hospital
# 37663  2019/20        Vancouver Island  West Coast General Hospital
# 37664  2019/20        Vancouver Island  West Coast General Hospital
#
#                            prcd waiting     comp  median_wait_w  wait_90_w
# 34273            Abdominoplasty     126      171           15.0       53.9
# ...

# %%
wl_kgh = wl[wl['hosp'] == 'Kelowna General Hospital']
wl_kgh
# Out:
#           year        HA                      hosp  \
# 1087   2009/10  Interior  Kelowna General Hospital
# 1088   2009/10  Interior  Kelowna General Hospital
# 1089   2009/10  Interior  Kelowna General Hospital
# 1090   2009/10  Interior  Kelowna General Hospital
# 1091   2009/10  Interior  Kelowna General Hospital
# ...        ...       ...                       ...
# 35437  2019/20  Interior  Kelowna General Hospital
# 35438  2019/20  Interior  Kelowna General Hospital
# 35439  2019/20  Interior  Kelowna General Hospital
# 35440  2019/20  Interior  Kelowna General Hospital
# 35441  2019/20  Interior  Kelowna General Hospital
#
#                                       prcd waiting    comp  median_wait_w  \
# 1087                        Abdominoplasty       0      <5            NaN
# 1088                  All Other Procedures      61     290            4.0
# 1089                        All Procedures   4,053  10,397            6.0
# ...

# %%
wl_kgh_19_20 = wl[(wl['hosp'] == 'Kelowna General Hospital') & (wl['year'] == '2019/20')]
wl_kgh_19_20
# Out:
#           year        HA                      hosp  \
# 35360  2019/20  Interior  Kelowna General Hospital
# 35361  2019/20  Interior  Kelowna General Hospital
# 35362  2019/20  Interior  Kelowna General Hospital
# 35363  2019/20  Interior  Kelowna General Hospital
# 35364  2019/20  Interior  Kelowna General Hospital
# ...        ...       ...                       ...
# 35437  2019/20  Interior  Kelowna General Hospital
# 35438  2019/20  Interior  Kelowna General Hospital
# 35439  2019/20  Interior  Kelowna General Hospital
# 35440  2019/20  Interior  Kelowna General Hospital
# 35441  2019/20  Interior  Kelowna General Hospital
#
#                                       prcd waiting    comp  median_wait_w  \
# 35360                       Abdominoplasty      27      21           33.4
# 35361                 All Other Procedures     110     367            4.6
# 35362                       All Procedures   4,239  12,212            8.0
# ...

# %%
wl_all_knee= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Knee Replacement')]
wl_all_knee
# Out:
#           year                      HA            hosp              prcd  \
# 43     2009/10  All Health Authorities  All Facilities  Knee Replacement
# 3397   2010/11  All Health Authorities  All Facilities  Knee Replacement
# 6833   2011/12  All Health Authorities  All Facilities  Knee Replacement
# 10303  2012/13  All Health Authorities  All Facilities  Knee Replacement
# 13768  2013/14  All Health Authorities  All Facilities  Knee Replacement
# 17216  2014/15  All Health Authorities  All Facilities  Knee Replacement
# 20627  2015/16  All Health Authorities  All Facilities  Knee Replacement
# 24033  2016/17  All Health Authorities  All Facilities  Knee Replacement
# 27471  2017/18  All Health Authorities  All Facilities  Knee Replacement
# 30920  2018/19  All Health Authorities  All Facilities  Knee Replacement
# 34315  2019/20  All Health Authorities  All Facilities  Knee Replacement
#
#       waiting    comp  median_wait_w  wait_90_w
# ...

# %%
wl_all_ortho= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Other Orthopaedic Surgery')]
wl_all_ortho
# Out:
#           year                      HA            hosp  \
# 60     2009/10  All Health Authorities  All Facilities
# 3414   2010/11  All Health Authorities  All Facilities
# 6850   2011/12  All Health Authorities  All Facilities
# 10320  2012/13  All Health Authorities  All Facilities
# 13785  2013/14  All Health Authorities  All Facilities
# 17233  2014/15  All Health Authorities  All Facilities
# 20644  2015/16  All Health Authorities  All Facilities
# 24050  2016/17  All Health Authorities  All Facilities
# 27488  2017/18  All Health Authorities  All Facilities
# 30937  2018/19  All Health Authorities  All Facilities
# 34332  2019/20  All Health Authorities  All Facilities
#
#                             prcd waiting   comp  median_wait_w  wait_90_w
# 60     Other Orthopaedic Surgery   2,568  6,422            5.6       28.9
# 3414   Other Orthopaedic Surgery   2,656  6,424            6.1       31.4
# 6850   Other Orthopaedic Surgery   2,845  6,879            6.0       29.6
# ...

# %%
wl_all_prostate= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Prostate Surgery')]
wl_all_prostate
# Out:
#           year                      HA            hosp              prcd  \
# 63     2009/10  All Health Authorities  All Facilities  Prostate Surgery
# 3417   2010/11  All Health Authorities  All Facilities  Prostate Surgery
# 6853   2011/12  All Health Authorities  All Facilities  Prostate Surgery
# 10323  2012/13  All Health Authorities  All Facilities  Prostate Surgery
# 13788  2013/14  All Health Authorities  All Facilities  Prostate Surgery
# 17236  2014/15  All Health Authorities  All Facilities  Prostate Surgery
# 20647  2015/16  All Health Authorities  All Facilities  Prostate Surgery
# 24053  2016/17  All Health Authorities  All Facilities  Prostate Surgery
# 27491  2017/18  All Health Authorities  All Facilities  Prostate Surgery
# 30940  2018/19  All Health Authorities  All Facilities  Prostate Surgery
# 34335  2019/20  All Health Authorities  All Facilities  Prostate Surgery
#
#       waiting   comp  median_wait_w  wait_90_w
# ...

# %%
wl_all_uterine= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Uterine Surgery')]
wl_all_uterine
# Out:
#           year                      HA            hosp             prcd  \
# 79     2009/10  All Health Authorities  All Facilities  Uterine Surgery
# 3433   2010/11  All Health Authorities  All Facilities  Uterine Surgery
# 6869   2011/12  All Health Authorities  All Facilities  Uterine Surgery
# 10339  2012/13  All Health Authorities  All Facilities  Uterine Surgery
# 13804  2013/14  All Health Authorities  All Facilities  Uterine Surgery
# 17252  2014/15  All Health Authorities  All Facilities  Uterine Surgery
# 20663  2015/16  All Health Authorities  All Facilities  Uterine Surgery
# 24069  2016/17  All Health Authorities  All Facilities  Uterine Surgery
# 27507  2017/18  All Health Authorities  All Facilities  Uterine Surgery
# 30956  2018/19  All Health Authorities  All Facilities  Uterine Surgery
# 34351  2019/20  All Health Authorities  All Facilities  Uterine Surgery
#
#       waiting    comp  median_wait_w  wait_90_w
# 79      2,773  11,980            5.0       17.7
# ...

# %%
wl_all_eye= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Other Eye Surgery')]
wl_all_eye
# Out:
#           year                      HA            hosp               prcd  \
# 58     2009/10  All Health Authorities  All Facilities  Other Eye Surgery
# 3412   2010/11  All Health Authorities  All Facilities  Other Eye Surgery
# 6848   2011/12  All Health Authorities  All Facilities  Other Eye Surgery
# 10318  2012/13  All Health Authorities  All Facilities  Other Eye Surgery
# 13783  2013/14  All Health Authorities  All Facilities  Other Eye Surgery
# 17231  2014/15  All Health Authorities  All Facilities  Other Eye Surgery
# 20642  2015/16  All Health Authorities  All Facilities  Other Eye Surgery
# 24048  2016/17  All Health Authorities  All Facilities  Other Eye Surgery
# 27486  2017/18  All Health Authorities  All Facilities  Other Eye Surgery
# 30935  2018/19  All Health Authorities  All Facilities  Other Eye Surgery
# 34330  2019/20  All Health Authorities  All Facilities  Other Eye Surgery
#
#       waiting   comp  median_wait_w  wait_90_w
# ...

# %%
wl_all_cataract= wl[(wl['HA'] == 'All Health Authorities') & (wl['prcd']  == 'Cataract Surgery')]
wl_all_cataract
# Out:
#           year                      HA            hosp              prcd  \
# 12     2009/10  All Health Authorities  All Facilities  Cataract Surgery
# 3366   2010/11  All Health Authorities  All Facilities  Cataract Surgery
# 6803   2011/12  All Health Authorities  All Facilities  Cataract Surgery
# 10272  2012/13  All Health Authorities  All Facilities  Cataract Surgery
# 13737  2013/14  All Health Authorities  All Facilities  Cataract Surgery
# 17186  2014/15  All Health Authorities  All Facilities  Cataract Surgery
# 20597  2015/16  All Health Authorities  All Facilities  Cataract Surgery
# 24003  2016/17  All Health Authorities  All Facilities  Cataract Surgery
# 27441  2017/18  All Health Authorities  All Facilities  Cataract Surgery
# 30890  2018/19  All Health Authorities  All Facilities  Cataract Surgery
# 34285  2019/20  All Health Authorities  All Facilities  Cataract Surgery
#
#       waiting    comp  median_wait_w  wait_90_w
# ...

# %%
wl_all= wl[(wl['HA'] == 'All Health Authorities')]
wl_all
# Out:
#           year                      HA            hosp  \
# 0      2009/10  All Health Authorities  All Facilities
# 1      2009/10  All Health Authorities  All Facilities
# 2      2009/10  All Health Authorities  All Facilities
# 3      2009/10  All Health Authorities  All Facilities
# 4      2009/10  All Health Authorities  All Facilities
# ...        ...                     ...             ...
# 34352  2019/20  All Health Authorities  All Facilities
# 34353  2019/20  All Health Authorities  All Facilities
# 34354  2019/20  All Health Authorities  All Facilities
# 34355  2019/20  All Health Authorities  All Facilities
# 34356  2019/20  All Health Authorities  All Facilities
#
#                                       prcd waiting     comp  median_wait_w  \
# 0                           Abdominoplasty      52      100            9.1
# 1                     All Other Procedures   1,347    6,287            4.0
# 2                           All Procedures  72,056  219,284            5.3
# ...

# %%
wl_all_kgh = wl[(wl['prcd'] == 'All Procedures') & ((wl['hosp'] == 'Kelowna General Hospital')|(wl['hosp'] == 'All Facilities'))]
wl_all_kgh
# Out:
#           year                                    HA  \
# 2      2009/10                All Health Authorities
# 157    2009/10                                Fraser
# 860    2009/10                              Interior
# 1089   2009/10                              Interior
# 1567   2009/10                              Northern
# ...        ...                                   ...
# 35362  2019/20                              Interior
# 35830  2019/20                              Northern
# 36350  2019/20  Provincial Health Services Authority
# 36502  2019/20                     Vancouver Coastal
# 37099  2019/20                      Vancouver Island
#
#                            hosp            prcd waiting     comp  \
# 2                All Facilities  All Procedures  72,056  219,284
# 157              All Facilities  All Procedures  22,869   61,935
# 860              All Facilities  All Procedures  14,823   40,371
# ...

# %%
wl_kgh_all = wl[(wl['prcd'] == 'All Procedures') & (wl['hosp'] == 'Kelowna General Hospital')]
wl_kgh_all
# Out:
#           year        HA                      hosp            prcd waiting  \
# 1089   2009/10  Interior  Kelowna General Hospital  All Procedures   4,053
# 4442   2010/11  Interior  Kelowna General Hospital  All Procedures   3,650
# 7874   2011/12  Interior  Kelowna General Hospital  All Procedures   3,578
# 11357  2012/13  Interior  Kelowna General Hospital  All Procedures   3,327
# 14807  2013/14  Interior  Kelowna General Hospital  All Procedures   3,611
# 18258  2014/15  Interior  Kelowna General Hospital  All Procedures   3,884
# 21676  2015/16  Interior  Kelowna General Hospital  All Procedures   4,274
# 25079  2016/17  Interior  Kelowna General Hospital  All Procedures   4,295
# 28513  2017/18  Interior  Kelowna General Hospital  All Procedures   4,520
# 31959  2018/19  Interior  Kelowna General Hospital  All Procedures   4,272
# 35362  2019/20  Interior  Kelowna General Hospital  All Procedures   4,239
#
#          comp  median_wait_w  wait_90_w
# ...

# %%
wl_kgh_all.describe()
# Out:
#        median_wait_w  wait_90_w
# count      11.000000  11.000000
# mean        7.418182  31.390909
# std         1.163459   4.750675
# min         6.000000  25.100000
# 25%         6.400000  26.750000
# 50%         7.300000  30.100000
# 75%         8.500000  35.850000
# max         8.900000  36.900000

# %%
HA_stats = wl.groupby(by='HA').agg(['min','max'])
HA_stats
# Out:
#                                          year           \
#                                           min      max
# HA
# All Health Authorities                2009/10  2019/20
# Fraser                                2009/10  2019/20
# Interior                              2009/10  2019/20
# Northern                              2009/10  2019/20
# Provincial Health Services Authority  2009/10  2019/20
# Vancouver Coastal                     2009/10  2019/20
# Vancouver Island                      2009/10  2019/20
#
#                                                                                 hosp  \
#                                                                                  min
# HA
# All Health Authorities                                                All Facilities
# Fraser                                Abbotsford Regional Hospital And Cancer Centre
# Interior                                          100 Mile District General Hospital
# ...

# %%
wl_lt5_wait = wl[wl['waiting'] == '<5']
wl_lt5_wait
# Out:
#           year                      HA  \
# 33     2009/10  All Health Authorities
# 89     2009/10                  Fraser
# 97     2009/10                  Fraser
# 99     2009/10                  Fraser
# 109    2009/10                  Fraser
# ...        ...                     ...
# 37658  2019/20        Vancouver Island
# 37659  2019/20        Vancouver Island
# 37660  2019/20        Vancouver Island
# 37662  2019/20        Vancouver Island
# 37664  2019/20        Vancouver Island
#
#                                                  hosp  \
# 33                                     All Facilities
# 89     Abbotsford Regional Hospital And Cancer Centre
# 97     Abbotsford Regional Hospital And Cancer Centre
# 99     Abbotsford Regional Hospital And Cancer Centre
# 109    Abbotsford Regional Hospital And Cancer Centre
# ...                                               ...
# 37658                     West Coast General Hospital
# ...

# %%
wl_0_wait = wl[wl['waiting'] == '0']
wl_0_wait
# Out:
#           year                      HA  \
# 36     2009/10  All Health Authorities
# 98     2009/10                  Fraser
# 106    2009/10                  Fraser
# 110    2009/10                  Fraser
# 112    2009/10                  Fraser
# ...        ...                     ...
# 37641  2019/20        Vancouver Island
# 37642  2019/20        Vancouver Island
# 37643  2019/20        Vancouver Island
# 37646  2019/20        Vancouver Island
# 37663  2019/20        Vancouver Island
#
#                                                  hosp  \
# 36                                     All Facilities
# 98     Abbotsford Regional Hospital And Cancer Centre
# 106    Abbotsford Regional Hospital And Cancer Centre
# 110    Abbotsford Regional Hospital And Cancer Centre
# 112    Abbotsford Regional Hospital And Cancer Centre
# ...                                               ...
# 37641                     West Coast General Hospital
# ...

# %%
wl_lt5_comp = wl[wl['comp'] == '<5']
wl_lt5_comp
# Out:
#           year                      HA  \
# 36     2009/10  All Health Authorities
# 85     2009/10                  Fraser
# 89     2009/10                  Fraser
# 98     2009/10                  Fraser
# 106    2009/10                  Fraser
# ...        ...                     ...
# 37643  2019/20        Vancouver Island
# 37646  2019/20        Vancouver Island
# 37649  2019/20        Vancouver Island
# 37658  2019/20        Vancouver Island
# 37663  2019/20        Vancouver Island
#
#                                                  hosp  \
# 36                                     All Facilities
# 85     Abbotsford Regional Hospital And Cancer Centre
# 89     Abbotsford Regional Hospital And Cancer Centre
# 98     Abbotsford Regional Hospital And Cancer Centre
# 106    Abbotsford Regional Hospital And Cancer Centre
# ...                                               ...
# 37643                     West Coast General Hospital
# ...

# %%
wl_0_comp = wl[wl['comp'] == '0']
wl_0_comp
# Out:
#           year                HA                         hosp  \
# 172    2009/10            Fraser               All Facilities
# 271    2009/10            Fraser             Burnaby Hospital
# 420    2009/10            Fraser               Delta Hospital
# 449    2009/10            Fraser         Eagle Ridge Hospital
# 587    2009/10            Fraser   Pattison Outpatient Centre
# ...        ...               ...                          ...
# 37481  2019/20  Vancouver Island       Royal Jubilee Hospital
# 37524  2019/20  Vancouver Island   Saanich Peninsula Hospital
# 37539  2019/20  Vancouver Island   Saanich Peninsula Hospital
# 37553  2019/20  Vancouver Island   Saanich Peninsula Hospital
# 37660  2019/20  Vancouver Island  West Coast General Hospital
#
#                         prcd waiting comp  median_wait_w  wait_90_w
# 172             CSF Drainage      <5    0            NaN        NaN
# 271      Knee - Meniscectomy      <5    0            NaN        NaN
# ...

# %%
wl_25_comp = wl[wl['comp'] == '25']
wl_25_comp
# Out:
#           year                 HA                         hosp  \
# 385    2009/10             Fraser               Delta Hospital
# 422    2009/10             Fraser               Delta Hospital
# 423    2009/10             Fraser               Delta Hospital
# 530    2009/10             Fraser    Langley Memorial Hospital
# 582    2009/10             Fraser    Mission Memorial Hospital
# ...        ...                ...                          ...
# 36979  2019/20  Vancouver Coastal   Ubc Health Sciences Centre
# 37069  2019/20  Vancouver Coastal   Vancouver General Hospital
# 37542  2019/20   Vancouver Island   Saanich Peninsula Hospital
# 37579  2019/20   Vancouver Island    Victoria General Hospital
# 37631  2019/20   Vancouver Island  West Coast General Hospital
#
#                                 prcd waiting comp  median_wait_w  wait_90_w
# 385                   Dental Surgery      <5   25            1.9       17.7
# ...
